# %% [markdown]
# Porter Stemmer

# %%
import sys

class PorterStemmer:

    def __init__(self):
        """The main part of the stemming algorithm starts here.
        b is a buffer holding a word to be stemmed. The letters are in b[k0],
        b[k0+1] ... ending at b[k]. In fact k0 = 0 in this demo program. k is
        readjusted downwards as the stemming progresses. Zero termination is
        not in fact used in the algorithm.

        Note that only lower case sequences are stemmed. Forcing to lower case
        should be done before stem(...) is called.
        """

        self.b = ""  # buffer for word to be stemmed
        self.k = 0
        self.k0 = 0
        self.j = 0   # j is a general offset into the string

    def cons(self, i):
        """cons(i) is TRUE <=> b[i] is a consonant."""
        if self.b[i] == 'a' or self.b[i] == 'e' or self.b[i] == 'i' or self.b[i] == 'o' or self.b[i] == 'u':
            return 0
        if self.b[i] == 'y':
            if i == self.k0:
                return 1
            else:
                return (not self.cons(i - 1))
        return 1

    def m(self):
        """m() measures the number of consonant sequences between k0 and j.
        if c is a consonant sequence and v a vowel sequence, and <..>
        indicates arbitrary presence,

           <c><v>       gives 0
           <c>vc<v>     gives 1
           <c>vcvc<v>   gives 2
           <c>vcvcvc<v> gives 3
           ....
        """
        n = 0
        i = self.k0
        while 1:
            if i > self.j:
                return n
            if not self.cons(i):
                break
            i = i + 1
        i = i + 1
        while 1:
            while 1:
                if i > self.j:
                    return n
                if self.cons(i):
                    break
                i = i + 1
            i = i + 1
            n = n + 1
            while 1:
                if i > self.j:
                    return n
                if not self.cons(i):
                    break
                i = i + 1
            i = i + 1

    def vowelinstem(self):
        """vowelinstem() is TRUE <=> k0,...j contains a vowel"""
        for i in range(self.k0, self.j + 1):
            if not self.cons(i):
                return 1
        return 0

    def doublec(self, j):
        """doublec(j) is TRUE <=> j,(j-1) contain a double consonant."""
        if j < (self.k0 + 1):
            return 0
        if (self.b[j] != self.b[j-1]):
            return 0
        return self.cons(j)

    def cvc(self, i):
        """cvc(i) is TRUE <=> i-2,i-1,i has the form consonant - vowel - consonant
        and also if the second c is not w,x or y. this is used when trying to
        restore an e at the end of a short  e.g.

           cav(e), lov(e), hop(e), crim(e), but
           snow, box, tray.
        """
        if i < (self.k0 + 2) or not self.cons(i) or self.cons(i-1) or not self.cons(i-2):
            return 0
        ch = self.b[i]
        if ch == 'w' or ch == 'x' or ch == 'y':
            return 0
        return 1

    def ends(self, s):
        """ends(s) is TRUE <=> k0,...k ends with the string s."""
        length = len(s)
        if s[length - 1] != self.b[self.k]: # tiny speed-up
            return 0
        if length > (self.k - self.k0 + 1):
            return 0
        if self.b[self.k-length+1:self.k+1] != s:
            return 0
        self.j = self.k - length
        return 1

    def setto(self, s):
        """setto(s) sets (j+1),...k to the characters in the string s, readjusting k."""
        length = len(s)
        self.b = self.b[:self.j+1] + s + self.b[self.j+length+1:]
        self.k = self.j + length

    def r(self, s):
        """r(s) is used further down."""
        if self.m() > 0:
            self.setto(s)

    def step1ab(self):
        """step1ab() gets rid of plurals and -ed or -ing. e.g.

           caresses  ->  caress
           ponies    ->  poni
           ties      ->  ti
           caress    ->  caress
           cats      ->  cat

           feed      ->  feed
           agreed    ->  agree
           disabled  ->  disable

           matting   ->  mat
           mating    ->  mate
           meeting   ->  meet
           milling   ->  mill
           messing   ->  mess

           meetings  ->  meet
        """
        if self.b[self.k] == 's':
            if self.ends("sses"):
                self.k = self.k - 2
            elif self.ends("ies"):
                self.setto("i")
            elif self.b[self.k - 1] != 's':
                self.k = self.k - 1
        if self.ends("eed"):
            if self.m() > 0:
                self.k = self.k - 1
        elif (self.ends("ed") or self.ends("ing")) and self.vowelinstem():
            self.k = self.j
            if self.ends("at"):   self.setto("ate")
            elif self.ends("bl"): self.setto("ble")
            elif self.ends("iz"): self.setto("ize")
            elif self.doublec(self.k):
                self.k = self.k - 1
                ch = self.b[self.k]
                if ch == 'l' or ch == 's' or ch == 'z':
                    self.k = self.k + 1
            elif (self.m() == 1 and self.cvc(self.k)):
                self.setto("e")

    def step1c(self):
        """step1c() turns terminal y to i when there is another vowel in the stem."""
        if (self.ends("y") and self.vowelinstem()):
            self.b = self.b[:self.k] + 'i' + self.b[self.k+1:]

    def step2(self):
        """step2() maps double suffices to single ones.
        so -ization ( = -ize plus -ation) maps to -ize etc. note that the
        string before the suffix must give m() > 0.
        """
        if self.b[self.k - 1] == 'a':
            if self.ends("ational"):   self.r("ate")
            elif self.ends("tional"):  self.r("tion")
        elif self.b[self.k - 1] == 'c':
            if self.ends("enci"):      self.r("ence")
            elif self.ends("anci"):    self.r("ance")
        elif self.b[self.k - 1] == 'e':
            if self.ends("izer"):      self.r("ize")
        elif self.b[self.k - 1] == 'l':
            if self.ends("bli"):       self.r("ble") # --DEPARTURE--
            # To match the published algorithm, replace this phrase with
            #   if self.ends("abli"):      self.r("able")
            elif self.ends("alli"):    self.r("al")
            elif self.ends("entli"):   self.r("ent")
            elif self.ends("eli"):     self.r("e")
            elif self.ends("ousli"):   self.r("ous")
        elif self.b[self.k - 1] == 'o':
            if self.ends("ization"):   self.r("ize")
            elif self.ends("ation"):   self.r("ate")
            elif self.ends("ator"):    self.r("ate")
        elif self.b[self.k - 1] == 's':
            if self.ends("alism"):     self.r("al")
            elif self.ends("iveness"): self.r("ive")
            elif self.ends("fulness"): self.r("ful")
            elif self.ends("ousness"): self.r("ous")
        elif self.b[self.k - 1] == 't':
            if self.ends("aliti"):     self.r("al")
            elif self.ends("iviti"):   self.r("ive")
            elif self.ends("biliti"):  self.r("ble")
        elif self.b[self.k - 1] == 'g': # --DEPARTURE--
            if self.ends("logi"):      self.r("log")
        # To match the published algorithm, delete this phrase

    def step3(self):
        """step3() dels with -ic-, -full, -ness etc. similar strategy to step2."""
        if self.b[self.k] == 'e':
            if self.ends("icate"):     self.r("ic")
            elif self.ends("ative"):   self.r("")
            elif self.ends("alize"):   self.r("al")
        elif self.b[self.k] == 'i':
            if self.ends("iciti"):     self.r("ic")
        elif self.b[self.k] == 'l':
            if self.ends("ical"):      self.r("ic")
            elif self.ends("ful"):     self.r("")
        elif self.b[self.k] == 's':
            if self.ends("ness"):      self.r("")

    def step4(self):
        """step4() takes off -ant, -ence etc., in context <c>vcvc<v>."""
        if self.b[self.k - 1] == 'a':
            if self.ends("al"): pass
            else: return
        elif self.b[self.k - 1] == 'c':
            if self.ends("ance"): pass
            elif self.ends("ence"): pass
            else: return
        elif self.b[self.k - 1] == 'e':
            if self.ends("er"): pass
            else: return
        elif self.b[self.k - 1] == 'i':
            if self.ends("ic"): pass
            else: return
        elif self.b[self.k - 1] == 'l':
            if self.ends("able"): pass
            elif self.ends("ible"): pass
            else: return
        elif self.b[self.k - 1] == 'n':
            if self.ends("ant"): pass
            elif self.ends("ement"): pass
            elif self.ends("ment"): pass
            elif self.ends("ent"): pass
            else: return
        elif self.b[self.k - 1] == 'o':
            if self.ends("ion") and (self.b[self.j] == 's' or self.b[self.j] == 't'): pass
            elif self.ends("ou"): pass
            # takes care of -ous
            else: return
        elif self.b[self.k - 1] == 's':
            if self.ends("ism"): pass
            else: return
        elif self.b[self.k - 1] == 't':
            if self.ends("ate"): pass
            elif self.ends("iti"): pass
            else: return
        elif self.b[self.k - 1] == 'u':
            if self.ends("ous"): pass
            else: return
        elif self.b[self.k - 1] == 'v':
            if self.ends("ive"): pass
            else: return
        elif self.b[self.k - 1] == 'z':
            if self.ends("ize"): pass
            else: return
        else:
            return
        if self.m() > 1:
            self.k = self.j

    def step5(self):
        """step5() removes a final -e if m() > 1, and changes -ll to -l if
        m() > 1.
        """
        self.j = self.k
        if self.b[self.k] == 'e':
            a = self.m()
            if a > 1 or (a == 1 and not self.cvc(self.k-1)):
                self.k = self.k - 1
        if self.b[self.k] == 'l' and self.doublec(self.k) and self.m() > 1:
            self.k = self.k -1

    def stem(self, p, i, j):
        """In stem(p,i,j), p is a char pointer, and the string to be stemmed
        is from p[i] to p[j] inclusive. Typically i is zero and j is the
        offset to the last character of a string, (p[j+1] == '\0'). The
        stemmer adjusts the characters p[i] ... p[j] and returns the new
        end-point of the string, k. Stemming never increases word length, so
        i <= k <= j. To turn the stemmer into a module, declare 'stem' as
        extern, and delete the remainder of this file.
        """
        # copy the parameters into statics
        self.b = p
        self.k = j
        self.k0 = i
        if self.k <= self.k0 + 1:
            return self.b # --DEPARTURE--

        # With this line, strings of length 1 or 2 don't go through the
        # stemming process, although no mention is made of this in the
        # published algorithm. Remove the line to match the published
        # algorithm.

        self.step1ab()
        self.step1c()
        self.step2()
        self.step3()
        self.step4()
        self.step5()
        return self.b[self.k0:self.k+1]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from collections import Counter
import csv
import os
import math
import sys
import json
import nltk
import re
import numpy as np
stopwords = ['a', 'an', 'the', 'them', 'is', 'are', 'am', 'i', 'he', 'she', 'it', 'they']

def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    ret = ""
    for i in range(0, len(data)):
    	if data[i] in symbols:
    		ret+=' '
    	else:
    		ret += data[i] 
    return ret

def stemming(line, stopwords):
	p = PorterStemmer()
	output = []
	for c in line:
		if c == '' or c in stopwords:
			continue
		word = c.strip()
		if word.isalpha():
			word = word.lower()
		stemmed = p.stem(word, 0, len(word)-1)
		stemmed = stemmed.strip()
		if stemmed in stopwords or len(stemmed) < 3:
			continue
		if stemmed != '':
			output.append(stemmed)
		word = ''
	return output

def getQueries(filename):
	file = open(filename, 'r')
	queries = []
	while(True):
		str = file.readline()
		if(str == ""):
			break
		prev = 'A'
		curr = 'A'
		i = 0
		while(True):
			prev = curr
			curr = str[i]
			if(prev == '|' and curr == '|'):
				break
			i+=1
		#pre-processing
		text = remove_punctuation(str[i+1:])
		words = tokenization(text)
		stemmed = stemming(words, stopwords)
		queries.append(stemmed)
	file.close()
	return queries

def tokenization(line):
	return re.split(r'[,.:;"`\'\(\)\{\}\[\] ]+|\n', line)
    
def getWords(doc, type):
	if(type == 'p'):
		file = open('./drive/MyDrive/AILA_2019_dataset/Object_casedocs/'+doc, 'r')
		text = file.read()
		text = remove_punctuation(text)
		words = tokenization(text)
		return stemming(words, stopwords)
	else:
		file = open('./drive/MyDrive/AILA_2019_dataset/Object_statutes/'+doc, 'r')
		text = file.read()
		text = remove_punctuation(text)
		words = tokenization(text)
		return stemming(words, stopwords)

def getDictionary(text):
	dic = {}
	for word in text:
		if word in dic:
			dic[word] += 1
		else:
			dic[word] = 1
	return dic

def getTfIdf(allwords, text, lenDocs):
	cnt = getDictionary(text)
	tf = {}
	for word in cnt:
		tf[word] = cnt[word]/len(text)
	idf = {}
	for word in cnt:
		if word in allwords:
			idf[word] = math.log(lenDocs/allwords[word])
		else:
			idf[word] = 0
	tfIdf = {}
	for word in tf:
		tfIdf[word] = tf[word]*idf[word]
	return tfIdf

def getCosine(m1, m2):
	ret = 0
	sqrt1 = 0
	sqrt2 = 0
	for word in m1:
		if(word in m2):
			ret += m1[word]*m2[word]
	for word in m1:
		sqrt1 += m1[word]*m1[word]
	for word in m2:
		sqrt2 += m2[word]*m2[word]
	if(sqrt1 == 0):
		return 0
	if(sqrt2 == 0):
		return 0
	sqrt1 = math.sqrt(sqrt1)
	sqrt2 = math.sqrt(sqrt2)
	return ret/(sqrt1*sqrt2)

# %%
queryList = getQueries('./drive/MyDrive/AILA_2019_dataset/Query_doc.txt')
totalQueries = len(queryList)
print("step 1 complete")

#reading relevant and non-relevant documents of the queries
file = open('./drive/MyDrive/AILA_2019_dataset/relevance_judgments_priorcases.txt', 'r')
queryRel = []
queryNonRel = []
for i in range(0, totalQueries):
	queryRel.append([])
	queryNonRel.append([])

#filling queryRel and queryNonRel
while(True):
	str1 = file.readline()
	if(str1 == ''):
		break
	str1 = str1.split()
	if(int(str1[3]) == 0):
		queryNonRel[int(str1[0][6:])-1].append(str1[2])
	else:
		queryRel[int(str1[0][6:])-1].append(str1[2])
file.close()
print("step 2 complete")


#reading relevant and non-relevant documents of the queries
file = open('./drive/MyDrive/AILA_2019_dataset/relevance_judgments_statutes.txt', 'r')
queryRelS = []
queryNonRelS = []
for i in range(0, totalQueries):
	queryRelS.append([])
	queryNonRelS.append([])

#filling queryRel and queryNonRel
while(True):
	str1 = file.readline()
	if(str1 == ''):
		break
	str1 = str1.split()
	if(int(str1[3]) == 0):
		queryNonRelS[int(str1[0][6:])-1].append(str1[2])
	else:
		queryRelS[int(str1[0][6:])-1].append(str1[2])
file.close()
print("step 3 complete")
# Out:
# step 1 complete
# step 2 complete
# step 3 complete

# %% [markdown]
# For prior cases

# %%
# reading all casedocs and creating dictionary of words
# docs: ['C1.txt', 'C2.txt', .......]
# allwords: dictionary with key : word and value : no. of docs in which the word appears
# total: dictionary with key : doc_name and value : total no. of words in that document
# tfDocuments : dictionary with key : doc_name and value : a dictionary with (key : word, value : frequency of the word in that document)

docs = os.listdir("./drive/MyDrive/AILA_2019_dataset/Object_casedocs")
allwords = {}
avgDlen = 0
tfDocuments = {}
total = {}
for doc in docs:
	content = getWords(doc, 'p')
	avgDlen += len(content)
	cnt = Counter(content)
	total[doc] = len(content)
	tfDocuments[doc] = cnt
	for word in cnt:
		if word not in allwords:
			allwords[word]=1
		else:
			allwords[word]+=1
print("step 3 complete")

avgDlen = avgDlen/len(docs)

# idf : dictionary with key : word and value : idf value of that word
idf = {}
for word in allwords:
	idf[word] = math.log(len(docs)/allwords[word])


# tfIdfDocs : dictionary with key: doc_name, value : tfIdf value dictionary (word, float) of that document
tfIdfDocs = {}
for doc in docs:
	cnt = tfDocuments[doc]
	tf = {}
	for word in cnt:
		tf[word] = cnt[word]/total[doc]
	tfIdf = {}
	for word in tf:
		tfIdf[word] = tf[word]*idf[word]
	tfIdfDocs[doc] = tfIdf

print("step 4 complete")
#got tfIdf of each document in vector form
#find tfIdf of queries
tfIdfQueries = {}
for i in range(0, len(queryList)):
	tfIdfQueries[i] = getTfIdf(allwords, queryList[i], len(docs))
# Out:
# step 3 complete
# step 4 complete

# %%
graphRanksCase = []
graphRanksStatutes = []
for i in range(0, 10):
  graphRanksCase.append(0)
for i in range(0, 20):
  graphRanksStatutes.append(0)

# %%
print("FOR prior cases")
for i in range(0, len(queryList)):
	getResult = {}
	for doc in docs:
		getResult[doc] = getCosine(tfIdfQueries[i], tfIdfDocs[doc])
	l = []
	for doc in getResult:
		l.append((getResult[doc], doc))
	l.sort(key = lambda x: x[0])
	print("FOR query : "+str(i+1))
	print("Top five retrieved documents: ")
	for j in range(0, 5):
		string = l[len(l)-1-j][1]+" "+str(j+1)+" "+str(l[len(l)-1-j][0])
		print(string)
	print("Ranks of given relevant documents: ")
	for doc in queryRel[i]:
		for j in range(0, len(l)):
			if(l[len(l)-1-j][1] == doc+".txt"):
				print(doc+" "+str(j+1))
				rank = j+1
				if(rank < 1000 and rank >= 0):
					graphRanksCase[rank//100]+=1
				break
print("final finished")
# Out:
# FOR prior cases
# FOR query : 1
# Top five retrieved documents:
# C1240.txt 1 0.4325425079341901
# C1237.txt 2 0.32749082531313256
# C560.txt 3 0.3202995142402392
# C306.txt 4 0.30718183080913664
# C108.txt 5 0.30543748266887466
# Ranks of given relevant documents:
# C14 111
# C9 169
# FOR query : 2
# Top five retrieved documents:
# C2846.txt 1 0.33763271742662265
# C2316.txt 2 0.28670766673936415
# C1325.txt 3 0.2786610821040653
# C2462.txt 4 0.26854455011015854
# C2765.txt 5 0.24095522474966055
# Ranks of given relevant documents:
# C27 191
# C22 43
# FOR query : 3
# Top five retrieved documents:
# C277.txt 1 0.5164278970142034
# C246.txt 2 0.4778050709613326
# C2431.txt 3 0.35172967288566764
# C1036.txt 4 0.3337152039309148
# C294.txt 5 0.3240255986161211
# Ranks of given relevant documents:
# C1 586
# FOR query : 4
# Top five retrieved documents:
# C1728.txt 1 0.29119739496445923
# C1254.txt 2 0.24233617964553592
# C2052.txt 3 0.2414594845455789
# C2585.txt 4 0.23676289084515054
# C1129.txt 5 0.2338567687675979
# Ranks of given relevant documents:
# C182 1989
# FOR query : 5
# Top five retrieved documents:
# C240.txt 1 0.18511831881745885
# C178.txt 2 0.18097708610233582
# C2827.txt 3 0.15534949481392465
# C1538.txt 4 0.14699916070232924
# C1328.txt 5 0.1456005568546245
# Ranks of given relevant documents:
# C54 601
# C36 405
# C155 370
# C144 330
# C121 233
# FOR query : 6
# Top five retrieved documents:
# C356.txt 1 0.2055880658120068
# C1364.txt 2 0.18427087856841504
# C1440.txt 3 0.16932959334341144
# C6.txt 4 0.1452166893942414
# C2397.txt 5 0.14005534203869185
# Ranks of given relevant documents:
# C152 477
# C26 538
# C19 1228
# C99 103
# FOR query : 7
# Top five retrieved documents:
# C1396.txt 1 0.22934161866257086
# C1630.txt 2 0.21319555315187175
# C1948.txt 3 0.19128443397195968
# C2890.txt 4 0.18329558948354702
# C2853.txt 5 0.17870111840047118
# Ranks of given relevant documents:
# C130 950
# FOR query : 8
# Top five retrieved documents:
# C2822.txt 1 0.36864891752554557
# C600.txt 2 0.33130298169073064
# C428.txt 3 0.3074462768698924
# C1329.txt 4 0.30290163762508304
# C363.txt 5 0.30250120123762925
# Ranks of given relevant documents:
# C32 306
# C125 2823
# C60 2848
# FOR query : 9
# Top five retrieved documents:
# C1173.txt 1 0.20083156271813582
# C1328.txt 2 0.1957875101397098
# C1756.txt 3 0.1930749198459669
# C532.txt 4 0.1865582517332846
# C2799.txt 5 0.17967903268175006
# Ranks of given relevant documents:
# C42 922
# C90 486
# FOR query : 10
# Top five retrieved documents:
# C2265.txt 1 0.3304600971028075
# C479.txt 2 0.29331306015602604
# C2409.txt 3 0.2930195819049129
# C1778.txt 4 0.28542722243231244
# C1167.txt 5 0.2787649252616453
# Ranks of given relevant documents:
# C185 245
# C180 411
# C86 1029
# FOR query : 11
# Top five retrieved documents:
# C360.txt 1 0.7068130471221815
# C132.txt 2 0.7006832276295825
# C2257.txt 3 0.6924766963120107
# C2389.txt 4 0.689989651292998
# C1354.txt 5 0.6856351258351298
# Ranks of given relevant documents:
# C131 21
# C132 2
# FOR query : 12
# Top five retrieved documents:
# C2158.txt 1 0.43736781948735753
# C499.txt 2 0.4294266115008059
# C1824.txt 3 0.42532387088273216
# C2246.txt 4 0.42308679392528964
# C2472.txt 5 0.41988453205806775
# Ranks of given relevant documents:
# C8 99
# FOR query : 13
# Top five retrieved documents:
# C1178.txt 1 0.4972582361196617
# C2640.txt 2 0.49270816463274875
# C2412.txt 3 0.42144935479590484
# C2022.txt 4 0.414656478759591
# C362.txt 5 0.39515165203193126
# Ranks of given relevant documents:
# C102 275
# C120 11
# C40 9
# FOR query : 14
# Top five retrieved documents:
# C46.txt 1 0.3420206513198747
# C762.txt 2 0.2407331157063864
# C538.txt 3 0.21009796232211833
# C2687.txt 4 0.17819186948646057
# C2537.txt 5 0.17766095259008097
# Ranks of given relevant documents:
# C46 1
# FOR query : 15
# Top five retrieved documents:
# C297.txt 1 0.6413581430733111
# C453.txt 2 0.20054104842430168
# C701.txt 3 0.17961305322595844
# C2538.txt 4 0.17774174789666672
# C1550.txt 5 0.17661376360193537
# Ranks of given relevant documents:
# C185 524
# FOR query : 16
# Top five retrieved documents:
# C1869.txt 1 0.2415460914064052
# C178.txt 2 0.23065476690951575
# C318.txt 3 0.2115989456646298
# C428.txt 4 0.2114442740963796
# C453.txt 5 0.18779604277375475
# Ranks of given relevant documents:
# C166 185
# C50 379
# FOR query : 17
# Top five retrieved documents:
# C2158.txt 1 0.5922866121329123
# C360.txt 2 0.5805751991646156
# C2246.txt 3 0.5658040589301326
# C730.txt 4 0.5627288699698629
# C132.txt 5 0.5544782355423225
# Ranks of given relevant documents:
# C67 69
# C23 56
# C145 70
# FOR query : 18
# Top five retrieved documents:
# C188.txt 1 0.6650047445165539
# C115.txt 2 0.5981115333138156
# C2639.txt 3 0.518983271904077
# C116.txt 4 0.5184549997720385
# C2716.txt 5 0.5108260114394918
# Ranks of given relevant documents:
# C188 1
# FOR query : 19
# Top five retrieved documents:
# C2687.txt 1 0.22944144095239477
# C124.txt 2 0.22048779175041436
# C479.txt 3 0.2152225268865444
# C791.txt 4 0.21088663047536682
# C892.txt 5 0.21024446001965832
# Ranks of given relevant documents:
# C63 545
# C89 1026
# C77 88
# C142 1624
# FOR query : 20
# Top five retrieved documents:
# C1550.txt 1 0.2390501411642465
# C1402.txt 2 0.23129464978753456
# C892.txt 3 0.2167881863758433
# C1151.txt 4 0.21248979237780452
# C1513.txt 5 0.20682753102125706
# Ranks of given relevant documents:
# C134 1817
# C168 779
# FOR query : 21
# Top five retrieved documents:
# C113.txt 1 0.7028133106956862
# C1169.txt 2 0.39582968693540876
# C28.txt 3 0.39552134224901925
# C1714.txt 4 0.38432732552348103
# C1369.txt 5 0.381831989791944
# Ranks of given relevant documents:
# C48 600
# C28 3
# C114 113
# C113 1
# FOR query : 22
# Top five retrieved documents:
# C1728.txt 1 0.34942129498971114
# C210.txt 2 0.34675775789664565
# C845.txt 3 0.3433013717865528
# C363.txt 4 0.3210488768491783
# C686.txt 5 0.3123232313612621
# Ranks of given relevant documents:
# C11 1528
# C118 1148
# FOR query : 23
# Top five retrieved documents:
# C2468.txt 1 0.26777826537606353
# C1867.txt 2 0.26174298717908795
# C191.txt 3 0.2589772263611106
# C1412.txt 4 0.23397745230618353
# C2611.txt 5 0.22390745752090596
# Ranks of given relevant documents:
# C88 192
# C10 1076
# FOR query : 24
# Top five retrieved documents:
# C1511.txt 1 0.1790963658535027
# C1553.txt 2 0.16255666456755555
# C1000.txt 3 0.1525375353203566
# C1570.txt 4 0.15079926958722029
# C1711.txt 5 0.1437388196031808
# Ranks of given relevant documents:
# C171 80
# FOR query : 25
# Top five retrieved documents:
# C755.txt 1 0.4316053919747467
# C2624.txt 2 0.42670155070214055
# C1224.txt 3 0.4257747726665713
# C2702.txt 4 0.38738904033226584
# C2436.txt 5 0.38602512581622633
# Ranks of given relevant documents:
# C29 494
# C15 314
# C41 33
# C105 1221
# C17 748
# C84 15
# FOR query : 26
# Top five retrieved documents:
# C116.txt 1 0.44728476094071334
# C2350.txt 2 0.4256126144292003
# C2639.txt 3 0.423655453587451
# C2716.txt 4 0.42209939385344675
# C2668.txt 5 0.42135340591424997
# Ranks of given relevant documents:
# C116 1
# C115 26
# C44 15
# C183 10
# C179 17
# C108 653
# C133 181
# C87 64
# FOR query : 27
# Top five retrieved documents:
# C1655.txt 1 0.3446539283385726
# C375.txt 2 0.34021113942673453
# C366.txt 3 0.3171756259772816
# C91.txt 4 0.26537215972155204
# C1752.txt 5 0.25724358641187206
# Ranks of given relevant documents:
# C91 4
# C73 41
# C136 22
# C175 47
# C161 20
# FOR query : 28
# Top five retrieved documents:
# C2375.txt 1 0.15525910235968696
# C892.txt 2 0.13442481166016007
# C2909.txt 3 0.13055920324394668
# C490.txt 4 0.12850859169066634
# C1946.txt 5 0.12607779380329368
# Ranks of given relevant documents:
# C71 928
# C178 213
# FOR query : 29
# Top five retrieved documents:
# C1329.txt 1 0.1815518509670803
# C20.txt 2 0.1729575466300757
# C169.txt 3 0.16898857138786327
# C354.txt 4 0.15781608411696874
# C2878.txt 5 0.13432786569620978
# Ranks of given relevant documents:
# C66 486
# C6 340
# C127 1012
# C159 1841
# C173 641
# C24 2611
# C63 263
# C176 1181
# C156 415
# C62 17
# C153 2174
# C74 516
# C163 126
# C124 786
# C169 3
# C68 110
# C138 986
# C100 1539
# C34 606
# C140 1480
# C4 308
# C39 1944
# FOR query : 30
# Top five retrieved documents:
# C453.txt 1 0.4585673276908111
# C2822.txt 2 0.4263457607119639
# C1329.txt 3 0.3949421285399682
# C600.txt 4 0.3780585860037012
# C2538.txt 5 0.37645232766530784
# Ranks of given relevant documents:
# C148 83
# C80 258
# C137 1123
# C97 24
# C123 965
# C107 37
# C167 154
# C83 1371
# C154 211
# C56 106
# FOR query : 31
# Top five retrieved documents:
# C377.txt 1 0.2742110313726647
# C285.txt 2 0.2188714934413794
# C427.txt 3 0.21027004312200867
# C1612.txt 4 0.17993212770455488
# C480.txt 5 0.17656766993223183
# Ranks of given relevant documents:
# C93 104
# C65 72
# FOR query : 32
# Top five retrieved documents:
# C1769.txt 1 0.10795853663925507
# C657.txt 2 0.10438789001940463
# C1941.txt 3 0.08503281316914887
# C2519.txt 4 0.08343786709619366
# C2607.txt 5 0.0759035412030563
# Ranks of given relevant documents:
# C122 1052
# C164 1161
# C94 2024
# FOR query : 33
# Top five retrieved documents:
# C186.txt 1 0.22183195627339836
# C1663.txt 2 0.16979514536363596
# C1660.txt 3 0.16160635032630938
# C1764.txt 4 0.160806345070086
# C2195.txt 5 0.1518821998352835
# Ranks of given relevant documents:
# C186 1
# FOR query : 34
# Top five retrieved documents:
# C69.txt 1 0.2951727530006717
# C165.txt 2 0.29312524075218244
# C158.txt 3 0.2506971115388432
# C1306.txt 4 0.24259803415627332
# C2777.txt 5 0.23170360976719098
# Ranks of given relevant documents:
# C72 1593
# C49 1046
# C143 40
# C69 1
# C85 16
# C25 149
# C126 172
# C181 688
# C165 2
# C33 6
# C129 150
# C3 70
# C13 236
# FOR query : 35
# Top five retrieved documents:
# C351.txt 1 0.23797632034051672
# C2607.txt 2 0.22511461977416247
# C2505.txt 3 0.21004284594136732
# C892.txt 4 0.2080137133813814
# C178.txt 5 0.20048316399348967
# Ranks of given relevant documents:
# C31 55
# C184 62
# FOR query : 36
# Top five retrieved documents:
# C57.txt 1 0.44960231140958024
# C37.txt 2 0.37100751279239574
# C112.txt 3 0.32554704578668625
# C1483.txt 4 0.21193937830197904
# C318.txt 5 0.10599217576171673
# Ranks of given relevant documents:
# C57 1
# C112 3
# C172 443
# C160 1322
# C37 2
# C55 6
# FOR query : 37
# Top five retrieved documents:
# C2222.txt 1 0.24436673443244467
# C1821.txt 2 0.23586774441440236
# C2163.txt 3 0.22304738649968514
# C1379.txt 4 0.21972256969020548
# C2338.txt 5 0.2142903145903327
# Ranks of given relevant documents:
# C18 349
# C71 268
# C178 36
# FOR query : 38
# Top five retrieved documents:
# C1582.txt 1 0.29544493318477566
# C186.txt 2 0.2387021833562516
# C1147.txt 3 0.12858577198957885
# C103.txt 4 0.11623297679151574
# C1336.txt 5 0.10967184957699583
# Ranks of given relevant documents:
# C149 171
# C177 615
# C101 127
# C110 1264
# C70 2423
# FOR query : 39
# Top five retrieved documents:
# C1021.txt 1 0.20219677498532898
# C562.txt 2 0.19013886837948613
# C2904.txt 3 0.16881882531562747
# C2397.txt 4 0.1628290479118984
# C746.txt 5 0.15836266250254127
# Ranks of given relevant documents:
# C95 1218
# C16 11
# C53 1571
# C128 981
# C169 784
# C20 23
# C104 26
# C146 34
# C43 169
# C187 144
# C119 211
# C12 862
# FOR query : 40
# Top five retrieved documents:
# C2456.txt 1 0.49092961437167154
# C2441.txt 2 0.4847314466658353
# C1067.txt 3 0.48178048384492383
# C814.txt 4 0.45551418318429204
# C689.txt 5 0.4452723209664114
# Ranks of given relevant documents:
# C135 100
# C111 107
# FOR query : 41
# Top five retrieved documents:
# C1962.txt 1 0.3033356281573818
# C2764.txt 2 0.30019563696030926
# C1151.txt 3 0.2874779672033783
# C892.txt 4 0.28206046294272097
# C1379.txt 5 0.2767143089883941
# Ranks of given relevant documents:
# C98 964
# C96 325
# C35 94
# C52 105
# C94 387
# FOR query : 42
# Top five retrieved documents:
# C2563.txt 1 0.19403150399791372
# C2208.txt 2 0.13777941333398072
# C1640.txt 3 0.13744516204637394
# C677.txt 4 0.13702653439387447
# C425.txt 5 0.13445795844926722
# Ranks of given relevant documents:
# C103 456
# C81 289
# C150 23
# C2 73
# FOR query : 43
# Top five retrieved documents:
# C2822.txt 1 0.2557035199513927
# C908.txt 2 0.24312843382595556
# C2520.txt 3 0.2377048606831512
# C191.txt 4 0.2154189361668839
# C2515.txt 5 0.21359052093205078
# Ranks of given relevant documents:
# C157 1200
# C151 202
# C158 328
# FOR query : 44
# Top five retrieved documents:
# C2818.txt 1 0.32383881609475185
# C1887.txt 2 0.31052180891777
# C1593.txt 3 0.24870615216545616
# C1663.txt 4 0.24419550569165868
# C321.txt 5 0.20513786357280317
# Ranks of given relevant documents:
# C7 823
# C117 88
# C109 47
# C64 38
# C45 27
# C61 89
# FOR query : 45
# Top five retrieved documents:
# C892.txt 1 0.2867907683311454
# C1957.txt 2 0.27868925720544857
# C2590.txt 3 0.270099522681681
# C1099.txt 4 0.26438301961018024
# C1902.txt 5 0.2555058475066809
# Ranks of given relevant documents:
# C78 1482
# C58 554
# FOR query : 46
# Top five retrieved documents:
# C816.txt 1 0.349385464263832
# C773.txt 2 0.3458643931641399
# C139.txt 3 0.34046241218784995
# C1967.txt 4 0.3066740619419561
# C711.txt 5 0.29978856010028077
# Ranks of given relevant documents:
# C5 879
# C170 72
# C59 45
# C75 318
# C47 1427
# C106 160
# C79 2891
# C147 13
# C139 3
# FOR query : 47
# Top five retrieved documents:
# C1846.txt 1 0.29900696610155253
# C1578.txt 2 0.2681872368746804
# C1729.txt 3 0.2289150307136813
# C2340.txt 4 0.20910090128401085
# C1373.txt 5 0.19524630707103705
# Ranks of given relevant documents:
# C171 211
# FOR query : 48
# Top five retrieved documents:
# C1843.txt 1 0.3066833478043759
# C130.txt 2 0.30341640456946994
# C82.txt 3 0.2768063879245751
# C162.txt 4 0.25981166435398545
# C141.txt 5 0.2575734026887094
# Ranks of given relevant documents:
# C82 3
# C162 4
# C141 5
# C21 12
# FOR query : 49
# Top five retrieved documents:
# C2721.txt 1 0.4525545394260314
# C2853.txt 2 0.3871474268668212
# C2846.txt 3 0.29479070277638214
# C757.txt 4 0.25980596521416793
# C2644.txt 5 0.25548856978598866
# Ranks of given relevant documents:
# C174 146
# C38 927
# C76 279
# C92 128
# FOR query : 50
# Top five retrieved documents:
# C2846.txt 1 0.3115727158048541
# C2316.txt 2 0.2777042124253401
# C1325.txt 3 0.25495678419161893
# C2462.txt 4 0.24660173373763553
# C2765.txt 5 0.22056462401658847
# Ranks of given relevant documents:
# C27 52
# C22 33
# final finished

# %% [markdown]
# For statutes

# %%
# reading all casedocs and creating dictionary of words
# docs: ['C1.txt', 'C2.txt', .......]
# allwords: dictionary with key : word and value : no. of docs in which the word appears
# total: dictionary with key : doc_name and value : total no. of words in that document
# tfDocuments : dictionary with key : doc_name and value : a dictionary with (key : word, value : frequency of the word in that document)

docs = os.listdir("./drive/MyDrive/AILA_2019_dataset/Object_statutes")
allwords = {}
avgDlen = 0
tfDocuments = {}
total = {}
for doc in docs:
	content = getWords(doc, 's')
	avgDlen += len(content)
	cnt = Counter(content)
	total[doc] = len(content)
	tfDocuments[doc] = cnt
	for word in cnt:
		if word not in allwords:
			allwords[word]=1
		else:
			allwords[word]+=1
print("step 3 complete")

avgDlen = avgDlen/len(docs)

# idf : dictionary with key : word and value : idf value of that word
idf = {}
for word in allwords:
	idf[word] = math.log(len(docs)/allwords[word])


# tfIdfDocs : dictionary with key: doc_name, value : tfIdf value dictionary (word, float) of that document
tfIdfDocs = {}
for doc in docs:
	cnt = tfDocuments[doc]
	tf = {}
	for word in cnt:
		tf[word] = cnt[word]/total[doc]
	tfIdf = {}
	for word in tf:
		tfIdf[word] = tf[word]*idf[word]
	tfIdfDocs[doc] = tfIdf

print("step 4 complete")
#got tfIdf of each document in vector form
#find tfIdf of queries
tfIdfQueries = {}
for i in range(0, len(queryList)):
	tfIdfQueries[i] = getTfIdf(allwords, queryList[i], len(docs))
# Out:
# step 3 complete
# step 4 complete

# %% [markdown]
# For statutes

# %%
print("FOR statutes")
for i in range(0, len(queryList)):
	getResult = {}
	for doc in docs:
		getResult[doc] = getCosine(tfIdfQueries[i], tfIdfDocs[doc])
	l = []
	for doc in getResult:
		l.append((getResult[doc], doc))
	l.sort(key = lambda x: x[0])
	print("FOR query : "+str(i+1))
	print("Top five retrieved documents: ")
	for j in range(0, 5):
		string = l[len(l)-1-j][1]+" "+str(j+1)+" "+str(l[len(l)-1-j][0])
		print(string)
	print("Ranks of given relevant documents: ")
	for doc in queryRelS[i]:
		for j in range(0, len(l)):
			if(l[len(l)-1-j][1] == doc+".txt"):
				print(doc+" "+str(j+1))
				rank = j+1
				if(rank < 1000 and rank >= 0):
					graphRanksStatutes[rank//10]+=1
				break
print("final finished")
# Out:
# FOR statutes
# FOR query : 1
# Top five retrieved documents:
# S47.txt 1 0.22077638531296354
# S69.txt 2 0.1764897678534132
# S71.txt 3 0.1709898515991971
# S196.txt 4 0.16493141349197493
# S67.txt 5 0.16474457147520305
# Ranks of given relevant documents:
# S52 84
# S3 182
# S10 67
# S62 108
# FOR query : 2
# Top five retrieved documents:
# S38.txt 1 0.190016532313644
# S27.txt 2 0.18762394358913764
# S69.txt 3 0.18373187167246205
# S81.txt 4 0.16952440928770462
# S47.txt 5 0.15905300559373312
# Ranks of given relevant documents:
# S127 139
# S27 2
# FOR query : 3
# Top five retrieved documents:
# S196.txt 1 0.3754547948493519
# S69.txt 2 0.3025450956434345
# S81.txt 3 0.2896297222861756
# S134.txt 4 0.2687349717799247
# S184.txt 5 0.2575458557436183
# Ranks of given relevant documents:
# S134 4
# S33 16
# S184 5
# S23 28
# FOR query : 4
# Top five retrieved documents:
# S143.txt 1 0.24233902043501626
# S48.txt 2 0.15764130997963222
# S29.txt 3 0.15227674042967462
# S104.txt 4 0.13868260700674764
# S170.txt 5 0.13698942563573183
# Ranks of given relevant documents:
# S193 14
# S124 9
# S33 10
# S23 57
# FOR query : 5
# Top five retrieved documents:
# S81.txt 1 0.2641257386880712
# S69.txt 2 0.26297651281672985
# S29.txt 3 0.22552642734244316
# S196.txt 4 0.18829755108240018
# S161.txt 5 0.18156290768818392
# Ranks of given relevant documents:
# S19 117
# S6 59
# S13 81
# S24 113
# S64 143
# FOR query : 6
# Top five retrieved documents:
# S104.txt 1 0.16142661146409185
# S29.txt 2 0.15011132450928533
# S146.txt 3 0.1373153168363683
# S161.txt 4 0.1168670755069828
# S33.txt 5 0.10480128208559948
# Ranks of given relevant documents:
# S36 159
# S29 2
# S13 24
# S2 174
# S35 32
# FOR query : 7
# Top five retrieved documents:
# S168.txt 1 0.3159218577920782
# S81.txt 2 0.3101853929994683
# S69.txt 3 0.2840671822504087
# S47.txt 4 0.16840072248949986
# S17.txt 5 0.16583244542062336
# Ranks of given relevant documents:
# S49 117
# S27 26
# S127 167
# S168 1
# FOR query : 8
# Top five retrieved documents:
# S25.txt 1 0.2734028136008023
# S48.txt 2 0.25955889743902405
# S138.txt 3 0.2051169088530038
# S47.txt 4 0.1999277313564214
# S104.txt 5 0.1638757797507594
# Ranks of given relevant documents:
# S48 2
# S63 181
# S6 130
# S25 1
# S194 43
# FOR query : 9
# Top five retrieved documents:
# S29.txt 1 0.21900405668401168
# S196.txt 2 0.20021224074514965
# S161.txt 3 0.16854679450453683
# S69.txt 4 0.13745389853915457
# S146.txt 5 0.130420801323939
# Ranks of given relevant documents:
# S4 9
# S11 87
# S2 102
# S5 113
# S15 42
# FOR query : 10
# Top five retrieved documents:
# S11.txt 1 0.4426943081085683
# S107.txt 2 0.23721583066786228
# S69.txt 3 0.23176651600825157
# S81.txt 4 0.20615157238108472
# S64.txt 5 0.19950596242721758
# Ranks of given relevant documents:
# S21 14
# S13 6
# S6 15
# S11 1
# S4 20
# FOR query : 11
# Top five retrieved documents:
# S31.txt 1 0.4017356479398027
# S99.txt 2 0.3347955931404399
# S1.txt 3 0.26449887208008965
# S163.txt 4 0.23861751236849776
# S150.txt 5 0.21428063914321435
# Ranks of given relevant documents:
# S31 1
# S99 2
# S1 3
# S5 13
# FOR query : 12
# Top five retrieved documents:
# S149.txt 1 0.2702482918338981
# S163.txt 2 0.2229535494566135
# S31.txt 3 0.21422558314047402
# S150.txt 4 0.1637279679256903
# S99.txt 5 0.1426040242326108
# Ranks of given relevant documents:
# S163 2
# S117 180
# S129 182
# S2 10
# FOR query : 13
# Top five retrieved documents:
# S67.txt 1 0.14621376042266793
# S191.txt 2 0.14162698100448906
# S1.txt 3 0.12335788365388306
# S163.txt 4 0.12110291338016804
# S150.txt 5 0.11992038615066289
# Ranks of given relevant documents:
# S109 18
# S22 20
# S1 3
# S16 32
# S71 50
# FOR query : 14
# Top five retrieved documents:
# S29.txt 1 0.42773808961478094
# S161.txt 2 0.34283616459123306
# S81.txt 3 0.29740993942192506
# S69.txt 4 0.26896698121449775
# S146.txt 5 0.2368645252301352
# Ranks of given relevant documents:
# S86 39
# S12 124
# S6 40
# S2 21
# S76 178
# FOR query : 15
# Top five retrieved documents:
# S29.txt 1 0.2276296263397869
# S25.txt 2 0.2161425564376068
# S48.txt 3 0.19966822327931658
# S161.txt 4 0.19677893242334044
# S81.txt 5 0.1912814333282687
# Ranks of given relevant documents:
# S15 18
# S11 35
# S64 177
# S2 152
# FOR query : 16
# Top five retrieved documents:
# S47.txt 1 0.21098658163226158
# S81.txt 2 0.1954771637269406
# S69.txt 3 0.18461862063861753
# S170.txt 4 0.16338260761280313
# S71.txt 5 0.13270722206433339
# Ranks of given relevant documents:
# S43 34
# S24 52
# S2 113
# S13 58
# S51 92
# FOR query : 17
# Top five retrieved documents:
# S41.txt 1 0.296313928961131
# S31.txt 2 0.27200327776424327
# S40.txt 3 0.17944169102063978
# S99.txt 4 0.14832428073821244
# S163.txt 5 0.1444009874848819
# Ranks of given relevant documents:
# S99 4
# S5 55
# FOR query : 18
# Top five retrieved documents:
# S101.txt 1 0.3765001055072388
# S159.txt 2 0.3528303797034826
# S123.txt 3 0.3299553687012558
# S72.txt 4 0.27079484052864117
# S65.txt 5 0.2154651010619726
# Ranks of given relevant documents:
# S137 17
# S57 13
# S101 1
# S68 197
# FOR query : 19
# Top five retrieved documents:
# S29.txt 1 0.2630013907323618
# S161.txt 2 0.23445336917152193
# S81.txt 3 0.22665331053840138
# S146.txt 4 0.2208792580911027
# S167.txt 5 0.2132559309556046
# Ranks of given relevant documents:
# S15 109
# S21 141
# S11 12
# S76 151
# S2 39
# FOR query : 20
# Top five retrieved documents:
# S81.txt 1 0.2563831233574544
# S69.txt 2 0.21996262433251498
# S98.txt 3 0.2121337683905735
# S47.txt 4 0.1954633447475275
# S71.txt 5 0.15515366768753733
# Ranks of given relevant documents:
# S13 20
# S4 8
# S2 46
# S6 15
# FOR query : 21
# Top five retrieved documents:
# S42.txt 1 0.330860201661604
# S1.txt 2 0.2648064536602527
# S67.txt 3 0.1835129760879078
# S17.txt 4 0.16594767385489137
# S109.txt 5 0.1541669696820988
# Ranks of given relevant documents:
# S1 2
# S3 25
# S18 50
# S10 30
# FOR query : 22
# Top five retrieved documents:
# S69.txt 1 0.24290030144007954
# S81.txt 2 0.23215313112605804
# S29.txt 3 0.2209884599062424
# S25.txt 4 0.21575287153471936
# S48.txt 5 0.21547739348944253
# Ranks of given relevant documents:
# S63 7
# S6 104
# S124 20
# S48 5
# S25 4
# FOR query : 23
# Top five retrieved documents:
# S143.txt 1 0.17552412087766928
# S67.txt 2 0.10887373195063353
# S113.txt 3 0.09088357134825217
# S56.txt 4 0.08812494644556895
# S37.txt 5 0.08585415620958717
# Ranks of given relevant documents:
# S9 190
# S1 32
# S5 8
# S3 161
# S7 134
# FOR query : 24
# Top five retrieved documents:
# S47.txt 1 0.1684191564111301
# S81.txt 2 0.1532186405174675
# S196.txt 3 0.15124406334704318
# S102.txt 4 0.14804426976718973
# S69.txt 5 0.14235709952099668
# Ranks of given relevant documents:
# S19 165
# S24 118
# S43 19
# S2 186
# S6 14
# FOR query : 25
# Top five retrieved documents:
# S102.txt 1 0.34674311698897586
# S56.txt 2 0.27030696416913375
# S105.txt 3 0.2692009444687306
# S72.txt 4 0.26731017661486006
# S139.txt 5 0.2614571013425681
# Ranks of given relevant documents:
# S4 13
# S1 31
# S5 102
# S14 9
# S18 69
# FOR query : 26
# Top five retrieved documents:
# S159.txt 1 0.2464214831974156
# S123.txt 2 0.2168839249523197
# S93.txt 3 0.2036381121742325
# S101.txt 4 0.18100970894647186
# S47.txt 5 0.18078713981025385
# Ranks of given relevant documents:
# S123 2
# S158 10
# S101 4
# S4 42
# S185 94
# FOR query : 27
# Top five retrieved documents:
# S31.txt 1 0.2376561250364228
# S47.txt 2 0.1881860527646856
# S163.txt 3 0.16685033393689655
# S196.txt 4 0.15742574526595418
# S99.txt 5 0.15646937675897837
# Ranks of given relevant documents:
# S154 31
# S4 50
# S31 1
# S99 5
# FOR query : 28
# Top five retrieved documents:
# S69.txt 1 0.2188784217970882
# S81.txt 2 0.21683963450997906
# S196.txt 3 0.2134395280280217
# S27.txt 4 0.19679806009195494
# S17.txt 5 0.1732481704653236
# Ranks of given relevant documents:
# S21 134
# S115 23
# S6 37
# S2 82
# FOR query : 29
# Top five retrieved documents:
# S41.txt 1 0.2615585516121929
# S47.txt 2 0.22672972108311448
# S196.txt 3 0.1775307456924659
# S81.txt 4 0.16657137041577036
# S69.txt 5 0.15596070290704112
# Ranks of given relevant documents:
# S29 23
# S9 193
# S3 192
# S2 80
# FOR query : 30
# Top five retrieved documents:
# S25.txt 1 0.2821537784797252
# S48.txt 2 0.28008667723649866
# S138.txt 3 0.25174805869812494
# S98.txt 4 0.18560914237127987
# S170.txt 5 0.18034974843058973
# Ranks of given relevant documents:
# S2 118
# S63 26
# S6 41
# S29 10
# S25 1
# FOR query : 31
# Top five retrieved documents:
# S1.txt 1 0.23312354141932892
# S196.txt 2 0.2251293431440134
# S42.txt 3 0.1827231698922836
# S57.txt 4 0.1756892972083057
# S27.txt 5 0.16859001999569168
# Ranks of given relevant documents:
# S20 155
# S40 72
# S49 98
# S119 89
# S54 97
# FOR query : 32
# Top five retrieved documents:
# S104.txt 1 0.17582852028675644
# S81.txt 2 0.17163445597751986
# S146.txt 3 0.16492654187817765
# S47.txt 4 0.16453590217109984
# S69.txt 5 0.15529536894560572
# Ranks of given relevant documents:
# S64 131
# S19 149
# S2 54
# S11 101
# FOR query : 33
# Top five retrieved documents:
# S47.txt 1 0.20710017061494232
# S81.txt 2 0.19083609916094757
# S196.txt 3 0.18382944595141787
# S27.txt 4 0.18092814976480623
# S69.txt 5 0.17850758464194372
# Ranks of given relevant documents:
# S12 9
# S27 4
# S125 139
# FOR query : 34
# Top five retrieved documents:
# S144.txt 1 0.17698746348382424
# S143.txt 2 0.16055469294052113
# S1.txt 3 0.15111319716581437
# S179.txt 4 0.1441953498444851
# S27.txt 5 0.12461212422136878
# Ranks of given relevant documents:
# S111 30
# S104 8
# S146 13
# S39 17
# S5 34
# FOR query : 35
# Top five retrieved documents:
# S47.txt 1 0.2326314201722247
# S81.txt 2 0.15683153987363063
# S71.txt 3 0.1405839205638887
# S98.txt 4 0.13361379608081705
# S69.txt 5 0.13043515504543365
# Ranks of given relevant documents:
# S6 40
# S24 103
# S2 118
# S43 11
# S51 21
# FOR query : 36
# Top five retrieved documents:
# S1.txt 1 0.2228579531773036
# S170.txt 2 0.14197452825877296
# S143.txt 3 0.11619928214744556
# S198.txt 4 0.10845658857142927
# S5.txt 5 0.10195579662826408
# Ranks of given relevant documents:
# S3 157
# S16 73
# S18 84
# S9 197
# S175 160
# FOR query : 37
# Top five retrieved documents:
# S98.txt 1 0.21522352126302305
# S81.txt 2 0.206092985267021
# S29.txt 3 0.19827515718634514
# S69.txt 4 0.19718976227340518
# S161.txt 5 0.1644074059014999
# Ranks of given relevant documents:
# S64 70
# S6 38
# S34 116
# S19 125
# FOR query : 38
# Top five retrieved documents:
# S47.txt 1 0.24705354070958033
# S17.txt 2 0.23586452799063054
# S69.txt 3 0.21934616469340976
# S71.txt 4 0.19831233740381368
# S81.txt 5 0.19203059870618547
# Ranks of given relevant documents:
# S1 13
# S7 17
# S9 195
# S82 24
# FOR query : 39
# Top five retrieved documents:
# S29.txt 1 0.25508621339583354
# S167.txt 2 0.2484930831761169
# S156.txt 3 0.22931549882008437
# S81.txt 4 0.2273103752483836
# S146.txt 5 0.22108112573211808
# Ranks of given relevant documents:
# S153 12
# S136 146
# S115 11
# S129 195
# S2 115
# FOR query : 40
# Top five retrieved documents:
# S111.txt 1 0.198245051864014
# S16.txt 2 0.15290235058869442
# S82.txt 3 0.13341900906323897
# S1.txt 4 0.11925940094323344
# S182.txt 5 0.11491195080950528
# Ranks of given relevant documents:
# S30 191
# S10 15
# S3 32
# S1 4
# FOR query : 41
# Top five retrieved documents:
# S98.txt 1 0.31242313953494794
# S29.txt 2 0.1919355326255803
# S161.txt 3 0.16726207065679036
# S81.txt 4 0.15057024696981441
# S69.txt 5 0.13931194107668407
# Ranks of given relevant documents:
# S13 51
# S19 172
# S2 114
# S43 21
# S76 188
# FOR query : 42
# Top five retrieved documents:
# S47.txt 1 0.22028749944270387
# S77.txt 2 0.1690239943815336
# S71.txt 3 0.15278503511226726
# S17.txt 4 0.14636754997980314
# S93.txt 5 0.14100463662566695
# Ranks of given relevant documents:
# S20 77
# S33 42
# S54 114
# S23 56
# S53 17
# FOR query : 43
# Top five retrieved documents:
# S143.txt 1 0.3111835410682977
# S25.txt 2 0.2630586953693768
# S48.txt 3 0.22822021270318504
# S170.txt 4 0.1590192564688893
# S138.txt 5 0.15442120436727225
# Ranks of given relevant documents:
# S181 9
# S6 157
# S25 2
# S5 100
# S1 6
# FOR query : 44
# Top five retrieved documents:
# S1.txt 1 0.14934230658706504
# S57.txt 2 0.14553664273504074
# S104.txt 3 0.12626965865619655
# S144.txt 4 0.11813142385362922
# S170.txt 5 0.11645144286322215
# Ranks of given relevant documents:
# S39 10
# S127 153
# S12 104
# S27 11
# FOR query : 45
# Top five retrieved documents:
# S98.txt 1 0.20835310974476098
# S81.txt 2 0.20796893777842218
# S47.txt 3 0.2034313517940312
# S69.txt 4 0.17225533397469808
# S196.txt 5 0.1397674906528847
# Ranks of given relevant documents:
# S15 121
# S11 96
# S2 111
# S21 83
# FOR query : 46
# Top five retrieved documents:
# S81.txt 1 0.21048451092814485
# S69.txt 2 0.19277958421152613
# S146.txt 3 0.15073480540719186
# S29.txt 4 0.14547324704233602
# S104.txt 5 0.13847706450373448
# Ranks of given relevant documents:
# S167 71
# S2 87
# S156 85
# S197 58
# FOR query : 47
# Top five retrieved documents:
# S104.txt 1 0.34685141952791687
# S146.txt 2 0.3137188945188623
# S29.txt 3 0.2704615854563224
# S161.txt 4 0.2204380911249951
# S81.txt 5 0.2033018967581458
# Ranks of given relevant documents:
# S55 73
# S189 90
# S43 62
# S29 3
# S2 112
# FOR query : 48
# Top five retrieved documents:
# S144.txt 1 0.1973700267597872
# S179.txt 2 0.1955851965570145
# S104.txt 3 0.15086104739856868
# S146.txt 4 0.13482507539599786
# S57.txt 5 0.1220305684332089
# Ranks of given relevant documents:
# S12 90
# S40 28
# S168 161
# S20 53
# S62 98
# FOR query : 49
# Top five retrieved documents:
# S47.txt 1 0.2607170050022205
# S69.txt 2 0.21062957595101547
# S81.txt 3 0.20156880007847933
# S95.txt 4 0.19255781127284657
# S17.txt 5 0.18376974828775824
# Ranks of given relevant documents:
# S2 192
# S27 10
# S6 150
# FOR query : 50
# Top five retrieved documents:
# S69.txt 1 0.23571681817933784
# S38.txt 2 0.23201451987419425
# S27.txt 3 0.21452327844308267
# S81.txt 4 0.20920894039777257
# S47.txt 5 0.19349738450541085
# Ranks of given relevant documents:
# S127 137
# S27 3
# final finished

# %% [markdown]
# Graph for prior cases

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

data = []
data.append(graphRanksCase)
# data.append(counter9)
# data.append(counter10)

X = np.arange(10,110,10)
plt.bar(X+0, data[0], color = 'b', width = 1)
# plt.bar(X+1.25, data[1], color = 'r', width = 1)
# plt.bar(X+2.50, data[2], color = 'g', width = 1)
plt.xlabel("Relevant Document Rank ")
plt.ylabel("Frequency")
plt.title("Rank vs Relevant document frequency for Tf-IDF (scaled down by 0.1%)")
plt.show()

# %% [markdown]
# Graph for statutes

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

data = []
data.append(graphRanksStatutes)
# data.append(counter9)
# data.append(counter10)

X = np.arange(10,210,10)
plt.bar(X+0, data[0], color = 'b', width = 1)
# plt.bar(X+1.25, data[1], color = 'r', width = 1)
# plt.bar(X+2.50, data[2], color = 'g', width = 1)
plt.xlabel("Relevant Document Rank ")
plt.ylabel("Frequency")
plt.title("Rank vs Relevant document frequency for TF-IDF (scaled down by 0.1%)")
plt.show()
